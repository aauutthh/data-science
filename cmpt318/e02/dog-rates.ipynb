# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Load the data from the CSV into a DataFrame
# Assume a 'dog_rates_tweets.csv' file is in the same folder as the notebook
data = pd.read_csv("./dog_rates_tweets.csv")

# %%
# Find tweets that contain an 'n/10' rating (because not all do)
def get_rating(tweet):
    m = re.findall('(\d+(\.\d+)?)/10', tweet)
    if m :
        return float(m[0][0])
    else :
        return "None"
    
# Extract the numeric rating
data['rating'] = data['text'].apply(get_rating)

# Exclude tweets that don't contain a rating
data.drop(data[data.rating == "None"].index, inplace=True)

# %%
# Remove outliers: there are a few obvious ones
# Exclude rating values that are too large to make sense (Maybe larger than 25/10?)
data.drop(data[data.rating > 25].index, inplace=True)

# %%
# Make sure the 'created_at' column is a datetime value, not a string
# You can either do this by applying a function that parses the string to a date
# OR by asking Pandas' read_csv function to parse dates in that column with a parse_dates argument
data['created_at'] = pd.to_datetime(data['created_at'])

# %%
# scipy.stats.linregress function can do a linear regression for us
# But it works on numbers, not datetime objects
# So create a timestamp column
def to_timestamp(datetime):
    timestamp = datetime.timestamp()
    return timestamp
data['timestamp'] = data['created_at'].apply(to_timestamp)

# Now use linregress to get a slope and intercept for a best fit line
x = data['timestamp']
y = data['rating'].values
y = y.astype(float)
fit = stats.linregress(x, y)

# %%
# Create a scatter plot of date vs rating, so you can see what the data looks like
plt.xticks(rotation=25)
plt.plot(data['created_at'].values, y, 'b.', alpha=0.5)
plt.plot(data['created_at'].values, data['timestamp']*fit.slope + fit.intercept,'r-', linewidth=3)

# %%
# At the end of the notbook .. 
# Show the data itself
data
# Out:
#                       id          created_at  \
# 7     905222050297643008 2017-09-06 00:12:09
# 11    905175402502660096 2017-09-05 21:06:47
# 19    905098956430086144 2017-09-05 16:03:01
# 22    905079268476145665 2017-09-05 14:44:47
# 33    904495094014861312 2017-09-04 00:03:29
# 38    904363433650515968 2017-09-03 15:20:19
# 45    904128876116410369 2017-09-02 23:48:16
# 61    903288181222772736 2017-08-31 16:07:39
# 66    903047250515025922 2017-08-31 00:10:16
# 71    902923889638072321 2017-08-30 16:00:05
# 80    902561653547552769 2017-08-29 16:00:41
# 81    902322102602227712 2017-08-29 00:08:48
# 83    902236863959900163 2017-08-28 18:30:05
# 91    901564209359704068 2017-08-26 21:57:12
# 97    901527884283752448 2017-08-26 19:32:51
# 99    901505596159119364 2017-08-26 18:04:17
# 103   901484571857911808 2017-08-26 16:40:45
# 110   901234726886932482 2017-08-26 00:07:57
# 112   901204319462187008 2017-08-25 22:07:07
# 115   901096853307097089 2017-08-25 15:00:06
# 117   900881534437265408 2017-08-25 00:44:30
# 122   900742018732871681 2017-08-24 15:30:06
# 126   900502499592990721 2017-08-23 23:38:21
# 131   900391075784916992 2017-08-23 16:15:35
# 139   900149487678750720 2017-08-23 00:15:36
# 142   900070456102932480 2017-08-22 19:01:33
# 144   900025498180493312 2017-08-22 16:02:55
# 148   899783474726535170 2017-08-22 00:01:12
# 158   899028344733171712 2017-08-19 22:00:35
# 159   899013117614665729 2017-08-19 21:00:04
# ...                  ...                 ...
# 4221  700796979434098688 2016-02-19 21:39:54
# 122   b'This is Tally. She has never missed a sunris...     12  1.503614e+09
# 126   b"when you're being a good boy on your late af...     14  1.503557e+09
# 131   b'This is Darcy. She carries two tennis balls ...     13  1.503530e+09
# 139   b'Meet Finley. This was his first stick encoun...     12  1.503473e+09
# 142   b"This is Waffles. He's a windshield wiper cri...     13  1.503454e+09
# 144   b"This is Jada. She heard something exciting w...     12  1.503443e+09
# 148   b"Meet Bert. He's about to do a slurp. 13/10 w...     13  1.503385e+09
# 158   b'Meet Basil. A pup from @onetailatatime. He l...     12  1.503205e+09
# 159   b'This is Charlie. His owner went to the store...     13  1.503202e+09
# ...                                                 ...    ...           ...
# 4221  b"This is Daniel. He's a neat pup. Exotic af. ...      7  1.455947e+09
# 4222  b'We only rate dogs. Pls stop sending in non-c...     11  1.455935e+09
# 4226  b"This is Vincent. He's the man your girl is w...     10  1.455880e+09
# 4227  b"This is Kaia. She's just cute as hell. 12/10...     12  1.455877e+09
# 4228  b"This is Murphy. He's a mini golden retriever...      6  1.455867e+09
# 4230  b"This is Dotsy. She's stuck as hell. 10/10 ht...     10  1.455797e+09
# 4231  b"If a pupper gave that to me I'd probably sta...     11  1.455793e+09
# 4232  b"When it's Janet from accounting's birthday b...     10  1.455791e+09
# 4234  b"This is Eazy-E. He's colorful af. Must be ra...      6  1.455772e+09
# 4236  b'This is Coops. His ship is taking on water. ...     10  1.455764e+09
# 4237  b"This is Thumas. He covered himself in nanner...      9  1.455757e+09
# 4239  b'This is Cooper. He began to tear up when his...     11  1.455710e+09
# 4240  b"Say hello to Nala. She's a Freckled High Bru...     12  1.455706e+09
# 4241  b'Take all my money. 10/10 https://t.co/B28ebc...     10  1.455704e+09
# 4242  b"Meet Fillup. Spaghetti is his main weakness....     11  1.455703e+09
# 4246  b"This is Dave. He's a tropical pup. Short lil...      5  1.455683e+09
# 4248  b"This is Archie. He's undercover in all these...     12  1.455625e+09
# 4249  b"I know this is a tad late but here's a wonde...     12  1.455622e+09
# 4250  b'"Don\'t ever talk to me or my son again." .....     10  1.455619e+09
# 4251  b"Meet Miley. She's a Scandinavian Hollabackgi...     11  1.455617e+09
# 4252  b"Say hello to Calbert. He doesn't have enough...     11  1.455607e+09
# 4253  b'"I\'m bathing the children what do you want?...     10  1.455595e+09
# 4255  b"This is Charl. He's a bully. Chucks that dum...      3  1.455539e+09
# 4256  b"Meet Reagan. He's a Persnicketus Derpson. Gr...      8  1.455537e+09
# 4257  b'ERMAHGERD 12/10 please enjoy https://t.co/7W...     12  1.455536e+09
# 4260  b'This is Yukon. He pukes rainbows. 12/10 magi...     12  1.455533e+09
# 4262  b'HAPPY V-DAY FROM YOUR FAV PUPPER SQUAD 13/10...     13  1.455527e+09
# 4263  b'This is Oliver. He does toe touches in his s...     13  1.455516e+09
# 4264  b'Meet CeCe. She wanted to take a selfie befor...     11  1.455507e+09
# 4266  b"This dog is never sure if he's doing the rig...     10  1.455496e+09
#
# [1347 rows x 5 columns]

# %%
# ... the slope and intercept of the best-fit line ...
fit.slope, fit.intercept

# %%
# ... and a scatterplot with fit line
plt.show()
